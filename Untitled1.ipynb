# %%
import numpy as np
import pandas as pd

np.savetxt('C:\\Temp\\123.npy',np.array([[1, 2, 3], [4, 5, 6]]),fmt='%d')
a = np.loadtxt('C:\\Temp\\123.npy',dtype ='int')

df=pd.DataFrame(a,columns=list('ABC'))

# %%
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
